# %%
import subprocess
import sys
import os

# %%
subprocess.Popen(["start", "cmd", "/k", "streamlit", "run", "app.py"], shell=True)
# Out:
# <Popen: returncode: None args: ['start', 'cmd', '/k', 'streamlit', 'run', 'a...>
